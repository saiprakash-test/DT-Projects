# %%
# Loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the data
df=pd.read_csv('C:/Users/Admin/Desktop/Saiprakash/DT/Victims_of_rape.csv')

# %%
#head returns the first 5 rows 
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
#tail returns the last 5 rows 
df.tail()
# Out:
#         Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 1045  West Bengal  2009  Victims of Incest Rape                    3
# 1046  West Bengal  2009   Victims of Other Rape                 2333
# 1047  West Bengal  2010      Total Rape Victims                 2311
# 1048  West Bengal  2010  Victims of Incest Rape                    4
# 1049  West Bengal  2010   Victims of Other Rape                 2307
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1045                     0                          0
# 1046                     0                         18
# 1047                     0                         22
# 1048                     0                          1
# 1049                     0                         21
#
#       Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1045                          1                          1
# 1046                         84                       1834
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#displaying total number of rows and columns
df.shape
# Out:
# (1050, 11)

# %%
#displaying datatype of each column
df.dtypes
# Out:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object

# %%
#checking for the sum of null values if any
df.isnull().sum()
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
#calculating the statistical Statistics
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %% [markdown]
# # Data Visualizations

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# From the heatmap,it is clear that there are no null values.

# %%
#checking for unique values
df.nunique()
# Out:
# Area_Name                     35
# Year                          10
# Subgroup                       3
# Rape_Cases_Reported          429
# Victims_Above_50_Yrs          25
# Victims_Between_10-14_Yrs    139
# Victims_Between_14-18_Yrs    200
# Victims_Between_18-30_Yrs    364
# Victims_Between_30-50_Yrs    221
# Victims_of_Rape_Total        434
# Victims_Upto_10_Yrs           86
# dtype: int64

# %%
#checking the correlation
df.corr()
# Out:
#                                Year  Rape_Cases_Reported  \
# Year                       1.000000             0.070944
# Rape_Cases_Reported        0.070944             1.000000
# Victims_Above_50_Yrs       0.095368             0.652470
# Victims_Between_10-14_Yrs  0.057081             0.762842
# Victims_Between_14-18_Yrs  0.060579             0.780262
# Victims_Between_18-30_Yrs  0.069109             0.966432
# Victims_Between_30-50_Yrs  0.053460             0.925609
# Victims_of_Rape_Total      0.071121             0.999998
# Victims_Upto_10_Yrs        0.066608             0.665398
#
#                            Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# Year                                   0.095368                   0.057081
# Rape_Cases_Reported                    0.652470                   0.762842
# Victims_Above_50_Yrs                   1.000000                   0.595057
# Victims_Between_10-14_Yrs              0.595057                   1.000000
# ...

# %%
#visualizing the correlation
sns.heatmap(df.corr(),cmap='Blues',annot = True)

# %% [markdown]
# From the heatmap,Victims_Upto_10_Yrs has lowest correlation with Victims_Above_50_Yrs

# %%
# checking for outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                           5.00
# Rape_Cases_Reported          523.50
# Victims_Above_50_Yrs           1.00
# Victims_Between_10-14_Yrs     19.00
# Victims_Between_14-18_Yrs     42.00
# Victims_Between_18-30_Yrs    307.00
# Victims_Between_30-50_Yrs     58.75
# Victims_of_Rape_Total        527.50
# Victims_Upto_10_Yrs           11.00
# dtype: float64

# %%
(df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))
df1 = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df1
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1036                West Bengal  2006  Victims of Incest Rape
# 1039                West Bengal  2007  Victims of Incest Rape
# 1042                West Bengal  2008  Victims of Incest Rape
# 1045                West Bengal  2009  Victims of Incest Rape
# 1048                West Bengal  2010  Victims of Incest Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
df1.shape
# Out:
# (753, 11)

# %%
#1050 rows are reduced to 753.so,outliers are removed.

# %%
df1.skew()
# Out:
# Year                         0.047333
# Rape_Cases_Reported          2.960014
# Victims_Above_50_Yrs         2.984521
# Victims_Between_10-14_Yrs    2.573414
# Victims_Between_14-18_Yrs    2.649345
# Victims_Between_18-30_Yrs    3.487245
# Victims_Between_30-50_Yrs    2.858278
# Victims_of_Rape_Total        2.958449
# Victims_Upto_10_Yrs          2.509612
# dtype: float64

# %%
sns.distplot(df1['Rape_Cases_Reported'])

# %%
df['Rape_Cases_Reported'] = np.log(1+df['Rape_Cases_Reported'])

# %%
sns.distplot(df1['Rape_Cases_Reported'])

# %%
sns.scatterplot(data=df1,x='Victims_Between_18-30_Yrs',y='Victims_of_Rape_Total')

# %%
sns.pairplot(df1)

# %%
sns.scatterplot(data=df1,x='Victims_Upto_10_Yrs',y='Rape_Cases_Reported')

# %%
sns.scatterplot(data=df1,y='Victims_of_Rape_Total',x='Rape_Cases_Reported')
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
#from the above scatter plot,it is clear that 'Victims_of_Rape_Total' and 'Rape_Cases_Reported' have linear relatonship.

# %%
#Sorting data w.r.t  maximum Rape_Cases_Reported
max_Rape_Cases_Reported=df1.sort_values(by='Rape_Cases_Reported',ascending=False)
max_Rape_Cases_Reported
# Out:
#        Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 144        Bihar  2009      Total Rape Victims                  929
# 146        Bihar  2009   Victims of Other Rape                  928
# 453    Jharkhand  2002      Total Rape Victims                  797
# 459    Jharkhand  2004      Total Rape Victims                  797
# 147        Bihar  2010      Total Rape Victims                  795
# ..           ...   ...                     ...                  ...
# 253  Daman & Diu  2005  Victims of Incest Rape                    0
# 541  Lakshadweep  2001  Victims of Incest Rape                    0
# 766       Odisha  2006  Victims of Incest Rape                    0
# 256  Daman & Diu  2006  Victims of Incest Rape                    0
# 691      Mizoram  2001  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 144                     0                         19
# ...

# %% [markdown]
# Bihar has most Rape_Cases_Reported

# %%
#Top 5 states with maximum Rape_Cases_Reported
max_Rape_Cases_Reported[1:6]
# Out:
#      Area_Name  Year               Subgroup  Rape_Cases_Reported  \
# 146      Bihar  2009  Victims of Other Rape                  928
# 453  Jharkhand  2002     Total Rape Victims                  797
# 459  Jharkhand  2004     Total Rape Victims                  797
# 147      Bihar  2010     Total Rape Victims                  795
# 149      Bihar  2010  Victims of Other Rape                  793
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 146                     0                         19
# 453                     0                          0
# 459                     0                          0
# 147                     0                         17
# 149                     0                         16
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 146                         32                        764
# 453                         43                        676
# 459                         43                        676
# ...

# %% [markdown]
# The above list are top 5 Rape_Cases_Reported

# %%
min_Rape_Cases_Reported=df1[df1["Rape_Cases_Reported"]==0] 
min_Rape_Cases_Reported
# Out:
#                       Area_Name  Year                Subgroup  \
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# 7     Andaman & Nicobar Islands  2003  Victims of Incest Rape
# 10    Andaman & Nicobar Islands  2004  Victims of Incest Rape
# 13    Andaman & Nicobar Islands  2005  Victims of Incest Rape
# 16    Andaman & Nicobar Islands  2006  Victims of Incest Rape
# ...                         ...   ...                     ...
# 958                     Tripura  2010  Victims of Incest Rape
# 976               Uttar Pradesh  2006  Victims of Incest Rape
# 991                 Uttarakhand  2001  Victims of Incest Rape
# 1021                West Bengal  2001  Victims of Incest Rape
# 1024                West Bengal  2002  Victims of Incest Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 4                       0                     0                          0
# ...

# %%
min_Rape_Cases_Reported.shape
# Out:
# (131, 11)

# %% [markdown]
# There are 131 states in which Rape_Cases_Reported are zero.So,we can say that the above shown states are safe to live.

# %%
#Sorting data w.r.t Victims_of_Rape_Total
Victims_of_Rape_Total=df1.sort_values(by='Victims_of_Rape_Total',ascending=False)
Victims_of_Rape_Total
# Out:
#             Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 144             Bihar  2009      Total Rape Victims                  929
# 146             Bihar  2009   Victims of Other Rape                  928
# 459         Jharkhand  2004      Total Rape Victims                  797
# 453         Jharkhand  2002      Total Rape Victims                  797
# 147             Bihar  2010      Total Rape Victims                  795
# ..                ...   ...                     ...                  ...
# 391  Himachal Pradesh  2001  Victims of Incest Rape                    0
# 361           Haryana  2001  Victims of Incest Rape                    0
# 322               Goa  2008  Victims of Incest Rape                    0
# 307               Goa  2003  Victims of Incest Rape                    0
# 301               Goa  2001  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# ...

# %% [markdown]
# Bihar has most 'Victims_of_Rape_Total' more

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
df2= df1.copy()
df2= df2.apply(LabelEncoder().fit_transform)
df2.head()
# Out:
#    Area_Name  Year  Subgroup  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# 0          0     0         0                    3                     0
# 1          0     0         1                    1                     0
# 2          0     0         2                    2                     0
# 3          0     1         0                    2                     0
# 4          0     1         1                    0                     0
#
#    Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                          0                          3
# 1                          0                          1
# 2                          0                          2
# 3                          0                          1
# 4                          0                          0
#
#    Victims_Between_18-30_Yrs  Victims_Between_30-50_Yrs  \
# 0                          0                          0
# 1                          0                          0
# ...

# %%
from scipy.stats import skew

for col in df2:
    print(col)
    print(skew(df2[col]))
    
    plt.figure()
    sns.distplot(df2[col])
    plt.show()
# Out:
# Area_Name
# -0.01682822265241223
# Year
# 0.04723889875177822
# Subgroup
# -0.002065673090427634
# Rape_Cases_Reported
# 1.5300306722056516
# Victims_Above_50_Yrs
# 2.9785721736815676
# Victims_Between_10-14_Yrs
# 2.218442971195617
# Victims_Between_14-18_Yrs
# 2.1686733360108135
# Victims_Between_18-30_Yrs
# 1.7328570300042923
# Victims_Between_30-50_Yrs
# 2.2165852666631145
# Victims_of_Rape_Total
# 1.53542417003493
# Victims_Upto_10_Yrs
# 2.490491348793745

# %%
#less skewness is present

# %%
x = df2.drop(columns=['Rape_Cases_Reported'])
y = df2[['Rape_Cases_Reported']]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.70848785, -1.55054342, -1.36535963, ..., -0.51932192,
#         -0.67338182, -0.55105755],
#        [-1.70848785, -1.55054342, -0.00181082, ..., -0.51932192,
#         -0.71507883, -0.55105755],
#        [-1.70848785, -1.55054342,  1.36173799, ..., -0.51932192,
#         -0.69423032, -0.55105755],
#        ...,
#        [ 1.71356707,  0.90747594, -0.00181082, ..., -0.51932192,
#         -0.54829078,  0.43176181],
#        [ 1.71356707,  1.25862156, -0.00181082, ..., -0.4548136 ,
#         -0.67338182, -0.55105755],
#        [ 1.71356707,  1.60976718, -0.00181082, ..., -0.4548136 ,
#         -0.65253331, -0.55105755]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring='r2').mean()
# Out:
# 0.9996031340889925

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)
lm=linear_model.LinearRegression()
lm.fit(x_train, y_train)
y_pred = lm.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.20537828427346624
# MSE: 0.11498321773227681
# RMSE: 0.33909175414963544

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# MAE: 0.34110619469026554
# MSE: 0.5229889380530979
# RMSE: 0.7231797411799489
# 0.9998085082296129

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
y_pred = dtr.predict(x_test)

from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:', r2_score(y_test,y_pred))
# Out:
# MAE: 0.4336283185840708
# MSE: 1.1061946902654867
# RMSE: 1.051757904779178
# r2_score: 0.9995949681451766

# %% [markdown]
# LinearRegression Model works quite good in victims of rape Dataset. Erros are small.

# %% [markdown]
# Conclusion:
#
# ==>Bihar has most Rape_Cases_Reported and Victims_of_Rape'.
#
# ==>'Victims_of_Rape_Total' and 'Rape_Cases_Reported' have linear relatonship.
#
# ==> DecisionTreeRegressor works best

# %%
#saving the best model with DecisionTreeRegressor,since it have less errors

# %%
#importing joblib
import joblib

#saving the model in a pickle file
joblib.dump(lm,'lm_Victims.pkl')
# Out:
# ['lm_Victims.pkl']
